# %% [markdown]
# <a href="https://colab.research.google.com/github/10810325/230711/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([1,3,5,3,1])

# %%
plt.plot([1,5,3,2,4])
plt.plot([4,2,3,5,1])
